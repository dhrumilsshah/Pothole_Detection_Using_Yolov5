# %%
import torch
from IPython.display import Image

# %%
# !python train.py --img 416 --batch 16 --epochs 30 --data dataset.yaml --cfg models/custom_yolov5s.yaml --weights yolov5s.pt --cache

# %%
Image(filename='runs/train/exp3/train_batch0.jpg', width = 1000)

# %%
# !python detect.py --source ../Pothole_data/test/images --weights runs/train/exp3/weights/best.pt
# Out:
# detect: weights=['runs/train/exp3/weights/best.pt'], source=../Pothole_data/test/images, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  2022-4-21 torch 1.11.0+cpu CPU
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/67 C:\Users\027972839\Downloads\Spring_22\CECS_553_Machine_Vision\Reports\Project\Pothole_data\test\images\img-105_jpg.rf.3fe9dff3d1631e79ecb480ff403bcb86.jpg: 640x640 2 potholes, Done. (0.297s)
# ...
